# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score, mean_squared_error
import warnings
warnings.filterwarnings('ignore')

plt.rcParams["font.family"] = ["SimSun", "Microsoft YaHei", "SimHei"]
plt.rcParams["axes.unicode_minus"] = False

lu = "E:/Demo/python/回归分析实践—某车企汽车年销量预测/data/数据-汽车销量预测.csv" 
n = "year"    
s = "sales"   

try:
    d = pd.read_csv(lu)
    print(f"读到数据啦，一共{d.shape[0]}行")
except:
    print(f"文件找不到啦！是不是路径错了: {lu}")
    exit()

X = d[[n]]
Y = d[s]

m_l = LinearRegression() 
m_l.fit(X, Y)
y_l = m_l.predict(X)

r2_l = r2_score(Y, y_l)
mse_l = mean_squared_error(Y, y_l)
print(f"直线R²：{r2_l:.4f}")
print(f"公式: Y = {m_l.coef_[0]:.4f}×X + {m_l.intercept_:.4f}")

best_k = 0 
best_r2 = -float('inf')
poly_m = {}

# 2, 3, 4阶
for k in [2, 3, 4]:
    p = PolynomialFeatures(degree=k)
    X_k = p.fit_transform(X)
    
    m_k = LinearRegression()
    m_k.fit(X_k, Y)
    y_k = m_k.predict(X_k)
    
    r2_k = r2_score(Y, y_k)
    poly_m[k] = (m_k, p, r2_k)
    
    if r2_k > best_r2:
        best_r2 = r2_k
        best_k = k

print(f"最好的是{best_k}阶，R²是：{best_r2:.4f}")

m_best, p_best, _ = poly_m[best_k]
y_best = m_best.predict(p_best.fit_transform(X)) # 最优曲线结果

# ln(Y) = a + b*X
Y_log = np.log(Y.replace(0, np.nan).dropna())
X_log = X.loc[Y_log.index]

m_exp = LinearRegression()
m_exp.fit(X_log, Y_log)
y_exp = np.exp(m_exp.predict(X_log))

r2_exp = r2_score(Y.loc[Y_log.index], y_exp)
print(f"加速线R²：{r2_exp:.4f}")

r_all = pd.DataFrame({
    '名字': ['直线', f'{best_k}阶曲线', '加速线'],
    'R²': [r2_l, best_r2, r2_exp]
})
print("R²:")
print(r_all)

# 选出R²最大的
best_mod_name = r_all.loc[r_all['R²'].idxmax()]['名字']
print(f"\n是: {best_mod_name}。")

# 预测未来3年
last_n = d[n].max()
n_f = pd.DataFrame({n: [last_n + 1, last_n + 2, last_n + 3]})

if '直线' in best_mod_name:
    y_f = m_l.predict(n_f)
elif '曲线' in best_mod_name:
    y_f = m_best.predict(p_best.transform(n_f))
else:
    y_f = np.exp(m_exp.predict(n_f))

gai_lu = pd.DataFrame({
    '年份': n_f[n],
    '销量(万)': y_f.round(2)
})
print("\n未来3年销量预测：")
print(gai_lu)
# Out:
# CSV数据导入成功，共14行2列
# 数据列名： ['year', 'sales']
#
# 【数据源质量审核结果】
# 1. 缺失值检查：
# 无缺失值
#
# 2. 异常值检查（数值型变量）：
# 已生成year的异常值检测图（图1）
# 已生成sales的异常值检测图（图1）
#
# 【数据预处理】
# 异常值已通过1.5倍四分位距法处理
# 字段映射完成：'year'→'year'，'sales'→'sales'
# 预处理后数据预览：
#      year  sales
# 0  1988.0   65.0
# 1  1989.0   59.0
# 2  1990.0   51.0
# 3  1991.0   71.0
# 4  1992.0  106.0
#
# 【线性回归拟合】
# 线性回归R²值：0.9430（越接近1拟合越好）
# 线性回归MSE值：169.9155（值越小误差越小）
# 线性回归方程：销量 = 13.1560×年份 + -26107.4440
# 已生成线性回归拟合图（图2）
#
# 【曲线拟合（多项式回归）】
# 最优多项式阶数：4阶，R²值：0.9476
# 已生成4阶多项式拟合图（图3）
#
# 【非线性回归拟合（指数模型）】
# 指数回归R²值：0.9231
# 指数回归方程：销量 = e^(-215.2367 + 0.1103×年份)
# 已生成指数回归拟合图（图4）
#
# 【模型比较与未来销量预测】
# 模型性能比较：
#       模型类型       R²值
# 0     线性回归  0.943029
# 1  4阶多项式回归  0.947569
# 2     指数回归  0.923067
#
# 最优模型：4阶多项式回归（R²值最高，拟合效果最好）
#
# 未来3年销量预测结果：
#      预测年份    预测销量
# 0  2002.0  248.04
# 1  2003.0  271.57
# 2  2004.0  297.72
# 已生成销量预测结果图（图5）
#
# 程序执行完成！输出文件清单：
# - 异常值检测图（多个PNG文件）
# - 线性回归拟合图（线性回归拟合_0234972.png）
# - 多项式拟合图（如2阶多项式拟合_0234972.png）
# ...

# %%
# Out:
# --- 1. 数据导入与预处理 ---
# CSV数据导入成功，共14行2列
# 数据列名： ['year', 'sales']
#
# 【数据源质量审核结果】
# 1. 缺失值检查：
# 无缺失值
#
# 【数据预处理】
# 异常值已通过1.5倍四分位距法处理
# 预处理后数据预览：
#      year  sales
# 0  1988.0   65.0
# 1  1989.0   59.0
# 2  1990.0   51.0
# 3  1991.0   71.0
# 4  1992.0  106.0
#
# --- 2. 线性回归拟合 ---
# 线性回归R²值：0.9430
# 线性回归MSE值：169.9155
# 线性回归方程：销量 = 13.1560×年份 + -26107.4440
# 已完成线性回归拟合图（图2）的绘制。
#
# --- 3. 曲线拟合（多项式回归）---
# 最优多项式阶数：4阶，R²值：0.9476
# 已完成4阶多项式拟合图（图3）的绘制。
#
# --- 4. 非线性回归拟合（指数模型）---
# 指数回归R²值：0.9231
# 指数回归方程：销量 = e^(-215.2367 + 0.1103×年份)
# 已完成指数回归拟合图（图4）的绘制。
#
# --- 5. 模型比较与未来销量预测 ---
# 模型性能比较：
#       模型类型       R²值
# 0     线性回归  0.943029
# 1  4阶多项式回归  0.947569
# 2     指数回归  0.923067
#
# 最优模型：4阶多项式回归（R²值最高：0.9476，拟合效果最好）
#
# 未来3年销量预测结果：
#      预测年份    预测销量
# 0  2002.0  248.04
# 1  2003.0  271.57
# 2  2004.0  297.72
# 已完成销量预测结果图（图5）的绘制。
#
# 程序执行完成！预测结果已保存至 '销量预测结果_0234972.csv'
# 所有图表已在内存中绘制，请在本地运行代码并取消 plt.savefig() 注释以保存图片。
